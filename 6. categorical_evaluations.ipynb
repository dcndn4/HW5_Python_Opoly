# %% [raw]
# 06-Stu
# 8:00 PM
# 8:15 PM
# 8:25 PM

# %% [markdown]
# <font color='red'>Comment</font>
#
# ## Will anyone present once complete? Andrew? Claire? Lilia? Sylvia?
#
# Here, we apply what we just saw.

# %% [markdown]
#  # Categorical Assessment

# %% [markdown]
# Every year, real estate properties are assessed for their value. There are key attributes that are considered when evaluating a property, and these include the condition, total number of rooms, number of bedrooms, bathrooms, etc. Use a parallel categories plot to plot these attributes as dimensions. Use the interactive features of parallel category plots to review how each dimension can affect the other.

# %%
import pandas as pd
import plotly.express as px
from pathlib import Path

# %% [markdown]
#  ### Prep Data

# %%
# Read in data

data_csv="C:/Users/CS_Knit_tinK_SC/Documents/My Data Sources/101421/allegheny_property_assessments.csv"

prop_assessments = pd.read_csv(
    data_csv, 
    index_col="LEGAL2", 
    low_memory=False
)

# %%
# Read in data
#prop_assessments = pd.read_csv(
#    Path("../Resources/allegheny_property_assessments.csv"), 
#    index_col="LEGAL2", 
#    low_memory=False  # Sylvia, you'd asked long ago about inferring. This chunks the load into chunks, which means it infers off only the first chunk. As such, infer may be faulty.
#).sample(50, replace=True)  # this is a 200 meg file :(, so we just take 50 random samples, allowing for same row being sampled many times.

# %% [markdown]
# <font color='red'>Comment</font>
#
# Take note. This is only displaying the head. You can take columns to see all columns, or df.iloc[:, :] to see what you want.
#
# But...the original csv was 200 megs, and we only used like 1k of it...not good for `git pull`, so I've cut it down to 3000 rows (26 megs).

# %% [markdown]
#  ### Slice Data

# %%
# Select list of columns
data = prop_assessments[["LOCALTOTAL", "USEDESC", "CONDITIONDESC", "TOTALROOMS", "BEDROOMS", "FULLBATHS"]]
data.head()
# Out:
#                            LOCALTOTAL      USEDESC CONDITIONDESC  TOTALROOMS  \
# LEGAL2
# UNIT 1405 & PARKING SPACE    263000.0  CONDOMINIUM       AVERAGE         3.0
# UNIT 1406 & PARKING SPACE    300000.0  CONDOMINIUM       AVERAGE         3.0
# UNIT 1802 & PARKING SPACE    470300.0  CONDOMINIUM       AVERAGE         4.0
# UNIT 1804 & PARKING SPACE    344800.0  CONDOMINIUM       AVERAGE         4.0
# UNIT 1105 & PARKING SPACE    227000.0  CONDOMINIUM          GOOD         3.0
#
#                            BEDROOMS  FULLBATHS
# LEGAL2
# UNIT 1405 & PARKING SPACE       1.0        1.0
# UNIT 1406 & PARKING SPACE       1.0        2.0
# UNIT 1802 & PARKING SPACE       2.0        2.0
# UNIT 1804 & PARKING SPACE       2.0        2.0
# UNIT 1105 & PARKING SPACE       1.0        1.0

# %% [markdown]
#  ### Plot Data

# %%
# Plot data
px.parallel_categories(
    data,
    dimensions=["USEDESC", "TOTALROOMS", "BEDROOMS", "FULLBATHS"],
    color="LOCALTOTAL" # "TOTALROOMS"
)

# %% [markdown]
# Q) Are there any identifiable patterns at the dimension level?
#
# How many bedrooms are there?
#
# As bedrooms go up, what happens to full baths?
#
# As total rooms go up, what happens to bedrooms?
