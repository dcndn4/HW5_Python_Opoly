# %%
import plotly.express as px
import pandas as pd
import os
from pathlib import Path
from dotenv import load_dotenv

# %% [markdown]
# ### Prep Token

# %%
# Read the Mapbox API key
load_dotenv()  # mac

# path = "C:/users/garth/.env"
home = Path.home() / ".env"  # windows 1/2
load_dotenv(home)  # windows 2/2

map_box_api = os.getenv("mapbox")

# Set the Mapbox API
px.set_mapbox_access_token(map_box_api)

# %% [markdown]
# ### Prep Data

# %%
# Read in data

pop_count="C:/Users/CS_Knit_tinK_SC/Documents/My Data Sources/101421/population_counts.csv"
#foreclosures = pd.read_csv(pop_count, index_col='filing_date', parse_dates=True, infer_datetime_format=True)


df = pd.read_csv(pop_count).drop_duplicates()
data_to_plot = df[["Year", "PopulationCount", "Latitude", "Longitude"]]
filtered_data = df[df["StateDesc"] == "California"]

# %% [markdown]
# ### Plot data

# %%
# Plot Data
map_plot = px.scatter_mapbox(
    filtered_data,  # replace with df to watch your computer slow to an absolute crawl!
    lat="Latitude",
    lon="Longitude",
    size="PopulationCount",
    color="CityName",
    zoom=4
)

# Display the map
map_plot.show()
# Out:
# <div>                            <div id="eb8f38e7-6464-4901-bf2f-4a285d3fe621" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eb8f38e7-6464-4901-bf2f-4a285d3fe621")) {                    Plotly.newPlot(                        "eb8f38e7-6464-4901-bf2f-4a285d3fe621",                        [{"hovertemplate":"CityName=Alameda<br>PopulationCount=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>","lat":[37.7650849031,37.7645625166,37.775929832,37.7811916268,37.7778322183,37.7691701721,37.7714922387,37.7698045486,37.7666413788,37.7596579223,37.753584501,37.7331115628,37.7431320606,37.7515279664,37.7596492992,37.7632235073,37.7830855135,37.7650849031,37.7645625166,37.775929832,37.7811916268,37.7778322183,37.7691701721,37.7714922387,37.7698045486,37.7666413788,37.7596579223,37.753584501,37.7331115628,37.7431320606,37.7515279664,37.7596492992,37.7632235073,37.7830855135],"legendgroup":"Alameda","lon":[-122.266489842,-122.231170131,-122.247776936,-122.266079332,-122.283597907,-122.285136575,-122.269058188,-122.258245428,-122.247540431,-122.234298564,-122.240032775,-122.241211914,-122.248971174,-122.256729369,-122.259970057,-122.272328908,-122.306498973,-122.266489842,-122.231170131,-122.247776936,-122.266079332,-122.283597907,-122.285136575,-122.269058188,-122.258245428,-122.247540431,-122.234298564,-122.240032775,-122.241211914,-122.248971174,-122.256729369,-122.259970057,-122.272328908,-122.306498973],"marker":{"color":"#636efa","size":[73812,3646,4107,4896,4722,4866,4640,4567,2928,4651,6259,6526,7074,4357,3183,3271,4119,73812,3646,4107,4896,4722,4866,4640,4567,2928,4651,6259,6526,7074,4357,3183,3271,4119],"sizemode":"area","sizeref":9481.5525},"mode":"markers","name":"Alameda","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"CityName=Alhambra<br>PopulationCount=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>","lat":[34.0839734383,34.1012449031,34.0951421487,34.0961676852,34.1039996898,34.0820626794,34.0909207045,34.0957201564,34.0869807008,34.0802793151,34.0736605777,34.0876623737,34.095187919,34.0821872967,34.0841556114,34.0832452578,34.0719029813,34.0764498389,34.0653167144,34.0710196323,34.0654918214,34.0839734383,34.1012449031,34.0951421487,34.0961676852,34.1039996898,34.0820626794,34.0909207045,34.0957201564,34.0869807008,34.0802793151,34.0736605777,34.0876623737,34.095187919,34.0821872967,34.0841556114,34.0832452578,34.0719029813,34.0764498389,34.0653167144,34.0710196323,34.0654918214],"legendgroup":"Alhambra","lon":[-118.135514119,-118.121802023,-118.137717692,-118.131602046,-118.132169594,-118.152649485,-118.153606642,-118.147241501,-118.140160949,-118.139020746,-118.139349034,-118.13028857,-118.118974009,-118.112757818,-118.120186809,-118.126062492,-118.12558776,-118.125985021,-118.140753823,-118.155044759,-118.150707726,-118.135514119,-118.121802023,-118.137717692,-118.131602046,-118.132169594,-118.152649485,-118.153606642,-118.147241501,-118.140160949,-118.139020746,-118.139349034,-118.13028857,-118.118974009,-118.112757818,-118.120186809,-118.126062492,-118.12558776,-118.125985021,-118.140753823,-118.155044759,-118.150707726],"marker":{"color":"#EF553B","size":[83089,4255,3858,4098,5654,3279,3464,4998,4686,4218,3206,3842,5447,4361,3802,3942,3387,4871,2596,5770,3355,83089,4255,3858,4098,5654,3279,3464,4998,4686,4218,3206,3842,5447,4361,3802,3942,3387,4871,2596,5770,3355],"sizemode":"area","sizeref":9481.5525},"mode":"markers","name":"Alhambra","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"CityName=Anaheim<br>PopulationCount=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>","lat":[33.8389076996,33.8576362735,33.8569694761,33.8564588116,33.8557291986,33.8668296663,33. ...
